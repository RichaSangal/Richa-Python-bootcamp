# %% [markdown]
# # Machine Learning
# ## Compulsory task

# %% [markdown]
# 1. For each of the following examples describe at least one possible input and
# output. Justify your answers:
# * 1.1 A self-driving car
# * 1.2 Netflix recommendation system
# * 1.3 Signature recognition
# * 1.4 Medical diagnosis

# %% [markdown]
# 1. Answer here
#
# |      | Input(s)                                       | Output     |
# | ---- | ----------- | ---------  |
# | 1.1  |Type of terrain: For example the car could go on mountain mode, sand mode, snow mode etc                    |    Corresponding Ideal speed and driving style for that mode based on terrain      |
# | 1.2  |    History on generes of Movies watched and preferred directors       |       New movie recommendations based on history of Generes and directors preferred     |
# | 1.3  |  The program could be given the no of strokes and bends in the signature as the input    |    Probabilty of signature match will be the output     |
# | 1.4  |     Inputs could be Age, family history, Symptoms, test results    |      Probability of getting a particular disease     |

# %% [markdown]
# 2. For each of the following case studies, determine whether it is appropriate to utilise regression or classification machine learning algorithms. Justify your answers:
# * 2.1 Classifying emails as promotion or social based on their content and metadata.
# * 2.2 Forecasting the stock price of a company based on historical data and market trends.
# * 2.3 Sorting images of animals into different species based on their visual features.
# * 2.4 Predicting the likelihood of a patient having a particular disease based on medical history and diagnostic test results.

# %% [markdown]
# 2. Answer here
#
# * 2.1 Classification of emails is a classification machine learning task as the input which is emails can be categorised into predefined classes like promotional, social, office, etc.
#
# * 2.2 Forecasting stock price will be a regression task as it requires forecasting ie giving a continuous output. It can do so by learning from the company’s historical data and market trends.
#
# * 2.3 This is a task of classification as the animals can be categorised into predefined buckets based on their features. Example Bird for the ones that have wings, insects, mammals etc.
#
# * 2.4 This is a regression task as this task requires prediction of the likelihood of the patient getting the disease. The likelihood could be estimated based on the test results and medical history

# %% [markdown]
# 3. For each of the following real-world problems, determine whether it is appropriate to utilise a supervised or unsupervised machine learning algorithm. Justify your answers:
# * 3.1 Detecting anomalies in a manufacturing process using sensor data without prior knowledge of specific anomaly patterns.
# * 3.2 Predicting customer lifetime value based on historical transaction data and customer demographics.
# * 3.3 Segmenting customer demographics based on their purchase history, browsing behaviour, and preferences.
# * 3.4 Analysing social media posts to categorise them into different themes.

# %% [markdown]
# 3. Answer here
#
# * 3.1 Unsupervised learning-  The machine needs to detect underlying paterns and detect anomolies without any prior knowledge of anomaly pattern.
#
# * 3.2 Supervised learning- As the program needs to predict lifetime value based on inputs such as historical transaction data and customer demographics it requires the supervised learning. It can learn from history and does not necessarily need to find patterns on its own.
#
# * 3.3 Supervised learning- as the program needs to segment customer demographics based on previous purchases and browsing patterns supervised learning can be used. Classification machine learning alogorithm could be used for this.
#
# * 3.4 Unsupervised learning-  The machine needs to categorise the social media posts into different themes and it needs to find patterns without any prior knowledge.

# %% [markdown]
# 4.
# For each of the following real-world problems, determine whether it is appropriate to utilise semi-supervised machine learning algorithms. Justify your answers:
# * 4.1 Predicting fraudulent financial transactions using a dataset where most transactions are labelled as fraudulent or legitimate.
# * 4.2 Analysing customer satisfaction surveys where only a small portion of the data is labelled with satisfaction ratings.
# * 4.3 Identifying spam emails in a dataset where the majority of emails are labelled.
# * 4.4 Predicting the probability of default for credit card applicants based on their complete financial and credit-related information.

# %% [markdown]
# 4. Answer here
#
# * 4.1 Semi-supervised learning will not be appropriate for predicting fraudulent transactions as most transcations are already labelled and there is no scope for data to find underlying patters on its own therefore supervised learning will be more appropriate.
#
# * 4.2 Semi-Supervised learning will be appropriate as only a small portion of data is labelled. This can be used as training set from which the machine can learn and also find patterns on its own in the data.
#
# * 4.3 Semi-supervised learning will not be appropriate to identify spam emails in the dataset as the majority of the emails are labelled and therefore there is limited scope for the machine to find patterns on its own.     Supervised learning will be more appropriate.
#
# * 4.4 Semi-supervised learning will not be appropriate as we have complete history on applicants and this data can be used for training the program and therefore supervised learning will be more appropriate as opposed to semi supervised learning.
